# %%
import torch
from torch import nn, optim
from torch.utils.data import TensorDataset, DataLoader

# Divide Data as Training-Set and Verification-Set.
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits
digits = load_digits()

# The 30% of Entire data are for Verify Data.
X = digits.data
Y = digits.target

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
# Re-define variables that got data from train_test_split() function.
X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.int64)
X_test = torch.tensor(X_test, dtype=torch.float32)
Y_test = torch.tensor(Y_test, dtype=torch.int64)

# %%
# Stack several Layers to construct Deep-Neural-Network(DNN).
k = 100
net = nn.Sequential(
    nn.Linear(64, k),
    nn.ReLU(),
    nn.Linear(k, k),
    nn.ReLU(),
    nn.Linear(k, k),
    nn.ReLU(),
    nn.Linear(k, k),
    nn.ReLU(),
    nn.Linear(k, 10)
)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters())

# Write DataLoader by Applying Training-Data.
ds = TensorDataset(X_train, Y_train)
loader = DataLoader(ds, batch_size=32, shuffle=True)

# %%
# Training and Testing model that increased more data.
train_losses = []
test_losses = []

for epoch in range(100):
    running_loss = 0.0
    print("\n")
    print("Before training each data of running_loss : ", running_loss)
    
    for i, (xx, yy) in enumerate(loader):
        y_pred = net(xx)
        loss = loss_fn(y_pred, yy)
        optimizer.zero_grad()
        
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    train_losses.append(running_loss / i)
    y_pred = net(X_test)
    test_loss = loss_fn(y_pred, Y_test)
    test_losses.append(test_loss.item())
    print("After trained each data of running_loss : ", running_loss)
# Out:
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.411621045321226
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.333748761564493
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.5274475812911987
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.3011045372113585
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.839246898889542
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.152511802814843
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.106252862140536
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.876218982040882
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.5484256363706663
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.9258154470007867
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.119239542633295
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.836329225450754
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.6556206569075584
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.797223925590515
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.2806420978158712
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.7508573482045904
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.8048755042254925
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  5.1683257217518985
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.302298199385405
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.6526178494095802
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.999126107315533
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.9245506178122014
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.214413460344076
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.1776432059705257
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.058803323248867
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.633020988374483
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.7204844024963677
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.7525996435433626
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.7254363298416138
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.9516634978353977
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.634611477027647
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.063098575919867
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.2688711937516928
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.403105463832617
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.654733467847109
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.5695220422931015
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.778193861246109
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.8792785331606865
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.9027599841356277
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.4017650727182627
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.418665856122971
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.4925442058593035
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.960895247757435
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.320256090839393
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.2364434115588665
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.745298790046945
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.3978952794568613
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.2639305889606476
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.7036039816739503
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.6661596787162125
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.0621053092181683
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.7370685238856822
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.997256629576441
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.000922073086258
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.586782354861498
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.34619916556403
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.862115528434515
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.4164107060059905
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.372470045254886
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.7357634864747524
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.7199514880776405
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.795739658176899
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.6800100468099117
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.9096473455429077
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.7964351984555833
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.008614804595709
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.442787534237141
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.8109819451346993
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.8924295231699944
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.231798604130745
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.153339520911686
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.9043295830488205
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.416619297116995
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.992569474503398
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.323639247981191
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.4842551797628403
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.7006511671934277
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.2684751823544502
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.4005572407040745
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.2903235368430614
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.1893892362713814
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.5648233741521835
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.3836696054786444
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.0674531050026417
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.613251280869008
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.818150367587805
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.9845119023229927
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.7986474471981637
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  4.618509532883763
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.2688783276826143
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.319259252399206
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.967783563246485
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  1.5400263373740017
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.857867637416348
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.659716210429906
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.2714036165270954
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.5773185938596725
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.518676582723856
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  3.5501937940716743
#
#
# Before training each data of running_loss :  0.0
# After trained each data of running_loss :  2.1509207864291966

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

print("Train-Losses")
plt.plot(train_losses)
# Out:
# Train-Losses

# %%
print("Test-Losses")
plt.plot(test_losses)
# Out:
# Test-Losses

# %%
# Maybe I should not combine this two results of 
# trainied and tested model data..
print("All Data")
plt.plot(train_losses)
plt.plot(test_losses)
# Out:
# All Data
